# %%
import matplotlib.pyplot as plt
import sys
from pathlib import Path
# %load_ext autoreload
# %autoreload 2
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))
from src.config import BRENT_DATA,EVENT_DATA,PROCESSED_EVENT_DATA 

from src.preprocessing import (
    load_oil_data,
    preprocess_dates,
    compute_log_returns,
    compute_rolling_volatility
)

from src.visualizations import (
    plot_price,
    plot_log_returns,
    plot_volatility,
    plot_change_point,
    plot_change_points,
    plot_change_points_with_events
)

from src.statistics import adf_test
from src.bayesian_model import (
    build_change_point_model,
    sample_model,
    summarize_trace,
    plot_trace
)
from src.change_point_detection import detect_change_points
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load data

# %%
oil_df = load_oil_data(BRENT_DATA)

# %%
events_df = load_oil_data(PROCESSED_EVENT_DATA)

# %%
events_df = preprocess_dates(events_df)

# %%
events_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date                                 29 non-null     datetime64[us]
#  1   Event                                29 non-null     str
#  2   Category                             29 non-null     str
#  3   Expected Impact on Brent Oil Prices  29 non-null     str
# dtypes: datetime64[us](1), str(3)
# memory usage: 1.0 KB

# %% [markdown]
# # Preprocess

# %%
oil_df = preprocess_dates(oil_df)

# %% [markdown]
# # Plot raw prices

# %%
plot_price(oil_df)

# %% [markdown]
# # log returns

# %%
oil_df = compute_log_returns(oil_df)

# %%
plot_log_returns(oil_df)

# %%
oil_df
# Out:
#            Date  Price  LogPrice  LogReturn
# 0    1987-05-21  18.45  2.915064  -0.009709
# 1    1987-05-22  18.55  2.920470   0.005405
# 2    1987-05-25  18.60  2.923162   0.002692
# 3    1987-05-26  18.63  2.924773   0.001612
# 4    1987-05-27  18.60  2.923162  -0.001612
# ...         ...    ...       ...        ...
# 9005 2022-11-08  96.85  4.573163  -0.030706
# 9006 2022-11-09  93.05  4.533137  -0.040026
# 9007 2022-11-10  94.25  4.545951   0.012814
# 9008 2022-11-11  96.37  4.568195   0.022244
# 9009 2022-11-14  93.59  4.538924  -0.029271
#
# [9010 rows x 4 columns]

# %% [markdown]
# # Volatility

# %%
oil_df = compute_rolling_volatility(oil_df)

# %%
plot_volatility(oil_df)

# %%
adf_test(oil_df["LogReturn"])
# Out:
# ==================================================
# Augmented Dickey-Fuller Test
# ==================================================
# ADF Statistic : -16.4271
# p-value       : 0.0000
#
# Critical Values
# 1%: -3.4311
# 5%: -2.8619
# 10%: -2.5669
#
# Series is stationary.
# (np.float64(-16.427113494485894),
#  np.float64(2.4985801611428892e-29),
#  28,
#  8981,
#  {'1%': np.float64(-3.4310783342658615),
#   '5%': np.float64(-2.861861876398633),
#   '10%': np.float64(-2.566941329781918)},
#  np.float64(-40421.4169199348))

# %% [markdown]
# # Detect breakpoints

# %%
breakpoints = detect_change_points(
    oil_df["Price"],
    penalty=15
)

breakpoints
# Out:
# [3160, 4370, 5090, 5980, 6980, 8720, 9010]

# %%
events_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date                                 29 non-null     str
#  1   Event                                29 non-null     str
#  2   Category                             29 non-null     str
#  3   Expected Impact on Brent Oil Prices  29 non-null     str
# dtypes: str(4)
# memory usage: 1.0 KB

# %%
plot_change_points_with_events(
    oil_df,
    events_df,
    breakpoints
)

# %%
data = oil_df["LogReturn"].values

# %% [markdown]
# # Build Model

# %%
model = build_change_point_model(data)

# %% [markdown]
# # Sample

# %%
trace = sample_model(model)
# Out:
# Multiprocess sampling (4 chains in 2 jobs)
# CompoundStep
# >Metropolis: [tau]
# >NUTS: [mu_1, mu_2, sigma]
# c:\Users\bemnet\Desktop\10academy\week10\change-point-analysis\venv\Lib\site-packages\rich\live.py:260:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
weekly_df = (
    oil_df
    .set_index("Date")
    .resample("W")
    .mean()
    .reset_index()
)

# %%
data_weekly = weekly_df["LogReturn"].values

# %%
model_weekly = build_change_point_model(data_weekly)

# %%
trace_weekly = sample_model(model_weekly)
# Out:
# Multiprocess sampling (4 chains in 2 jobs)
# CompoundStep
# >Metropolis: [tau]
# >NUTS: [mu_1, mu_2, sigma]
# c:\Users\bemnet\Desktop\10academy\week10\change-point-analysis\venv\Lib\site-packages\rich\live.py:260:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 trace_weekly = sample_model(model_weekly)
#
# File c:\Users\bemnet\Desktop\10academy\week10\change-point-analysis\src\bayesian_model.py:91, in sample_model(model)
#      87 def sample_model(model):
#      89     with model:
# ---> 91         trace = pm.sample(
#      92             draws=2000,
#      93             tune=1000,
#      94             chains=4,
#      95             target_accept=0.95,
#      96             random_seed=42,
#      97             return_inferencedata=True
#      98         )
#     100     return trace
#
# File c:\Users\bemnet\Desktop\10academy\week10\change-point-analysis\venv\Lib\site-packages\pymc\sampling\mcmc.py:995, in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, quiet, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, compile_kwargs, **kwargs)
#     991 t_sampling = time.time() - t_start
#     993 # Packaging, validating and returning the result was extracted
#     994 # into a function to make it easier to test and refactor.
# --> 995 return _sample_return(
#     996     run=run,
#     997     traces=trace if isinstance(trace, ZarrTrace) else traces,
#     998     tune=tune,
#     999     t_sampling=t_sampling,
#    1000     discard_tuned_samples=discard_tuned_samples,
#    1001     compute_convergence_checks=compute_convergence_checks,
#    1002     return_inferencedata=return_inferencedata,
#    1003     keep_warning_stat=keep_warning_stat,
#    1004     idata_kwargs=idata_kwargs or {},
#    1005     model=model,
#    1006     quiet=quiet,
#    1007 )
#
# File c:\Users\bemnet\Desktop\10academy\week10\change-point-analysis\venv\Lib\site-packages\pymc\sampling\mcmc.py:1123, in _sample_return(run, traces, tune, t_sampling, discard_tuned_samples, compute_convergence_checks, return_inferencedata, keep_warning_stat, idata_kwargs, model, quiet)
#    1121 # Pick and slice chains to keep the maximum number of samples
#    1122 if discard_tuned_samples:
# -> 1123     traces, length = _choose_chains(traces, tune)
#    1124 else:
#    1125     traces, length = _choose_chains(traces, 0)
#
# File c:\Users\bemnet\Desktop\10academy\week10\change-point-analysis\venv\Lib\site-packages\pymc\backends\base.py:633, in _choose_chains(traces, tune)
#     631 lengths = [max(0, len(trace) - tune) for trace in traces]
#     632 if not sum(lengths):
# --> 633     raise ValueError("Not enough samples to build a trace.")
#     635 idxs = np.argsort(lengths)
#     636 l_sort = np.array(lengths)[idxs]
#
# ValueError: Not enough samples to build a trace.

# %%
monthly_df = (
    oil_df
    .set_index("Date")
    .resample("ME")
    .mean()
    .reset_index()
)

# %%
print(len(monthly_df))
# Out:
# 427

# %%
data_monthly = monthly_df["LogReturn"].values

# %%
model_monthly = build_change_point_model(data_monthly)

# %%
trace_monthly = sample_model(model_monthly)
# Out:
# Multiprocess sampling (4 chains in 2 jobs)
# CompoundStep
# >Metropolis: [tau]
# >NUTS: [mu_1, mu_2, sigma]
# c:\Users\bemnet\Desktop\10academy\week10\change-point-analysis\venv\Lib\site-packages\rich\live.py:260:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 41329 seconds.
# There were 68 divergences after tuning. Increase `target_accept` or reparameterize.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %% [markdown]
# ## Summarize Trace

# %%
summary = summarize_trace(trace_monthly)

summary
# Out:
#           mean       sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# tau    216.992  146.941   0.000  414.000     15.845    2.988      90.0
# mu_1    -0.000    0.002  -0.002    0.001      0.000    0.000    1132.0
# mu_2     0.001    0.001  -0.001    0.003      0.000    0.000     119.0
# sigma    0.006    0.000   0.005    0.006      0.000    0.000     524.0
#
#        ess_tail  r_hat
# tau       190.0   1.02
# mu_1      305.0   1.01
# mu_2       44.0   1.02
# sigma     396.0   1.00

# %% [markdown]
# ## Plot Trace

# %%
plot_trace(trace)

# %% [markdown]
# # Estimated Change Point

# %%
tau_estimate = int(
    trace.posterior["tau"]
    .mean()
    .values
)

print(tau_estimate)

# %%
change_date = oil_df.iloc[tau_estimate]["Date"]

print(change_date)

# %%
plot_change_point(
    oil_df,
    tau_estimate
)
